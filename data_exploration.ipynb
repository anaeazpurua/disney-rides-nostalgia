# %% [markdown]
# # PROJECT 1
# ## Magic Kingdom Nostalgia-meter
# #### Diseny is banking on nostalgia
#
#
# Nostalgia is one of Walt Disney World's magic ingredients. Experiencing the same ride that you took as a child with your parents or grandparents can take you back to a time of happiness, or at least the fantasy of it.
#
# During a recent visit with my kids, I wondered how many of these attractions existed when I visited Magic Kingdom with my parents in the Summer of 1993. I also thought about the new rides that had opened since then and how we were experiencing those for the first time.
#
# - What rides were open the first time I visited? How was my parents visit different from the one I did with my kids?
# - What's the point?

# %% [markdown]
# Sources
#
# SVG Map Magic Kingdom
# (WT-shared) LtPowers, CC BY-SA 4.0 <https://creativecommons.org/licenses/by-sa/4.0>, via Wikimedia Commons
#
# To do
# #quitar un princess hall y splash
#
# Interesting things I discovered/would like to explore:
# Magic Kingdom parking lots are bigger than the park itself

# %%
import pandas as pd

# %%
import matplotlib 
import requests

# %%
#downloaded from https://cdn.touringplans.com/datasets/entities.csv
#How to cite the datasets in publications "name of the dataset", Disney World Ride Wait Time Datasets, 
#TouringPlans.com, Month and Year Published, URL Accessed, Date Month and Year You Accessed Them
#response = requests.get('https://cdn.touringplans.com/datasets/entities.csv')
#print(response)
#data = response.json() 

df = pd.read_csv('entities.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      95 non-null     object
#  1   name                      95 non-null     object
#  2   short_name                95 non-null     object
#  3   land                      95 non-null     object
#  4   opened_on                 95 non-null     object
#  5   duration                  94 non-null     float64
#  6   average_wait_per_hundred  73 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 5.3+ KB

# %%
df.head()
# Out:
#    code                                               name  \
# 0  AK01                            It's Tough to Be a Bug!
# 1  AK07                                Kilimanjaro Safaris
# 2  AK11  Expedition Everest - Legend of the Forbidden M...
# 3  AK14                                  Kali River Rapids
# 4  AK18                                           DINOSAUR
#
#                short_name              land   opened_on  duration  \
# 0  It's Tough to Be a Bug  Discovery Island  04/22/1998       8.0
# 1     Kilimanjaro Safaris            Africa  04/22/1998      20.0
# 2      Expedition Everest              Asia  04/07/2006       4.0
# 3       Kali River Rapids              Asia  02/15/1999      10.0
# 4                DINOSAUR   DinoLand U.S.A.  04/22/1998       3.5
#
#    average_wait_per_hundred
# 0                      12.0
# 1                       4.0
# 2                       4.0
# 3                       5.0
# 4                       3.0

# %%
#Checking how other parks are called because the head() only showed Animal Kingdom
df.head(30)
# Out:
#      code                                               name  \
# 0    AK01                            It's Tough to Be a Bug!
# 1    AK07                                Kilimanjaro Safaris
# 2    AK11  Expedition Everest - Legend of the Forbidden M...
# 3    AK14                                  Kali River Rapids
# 4    AK18                                           DINOSAUR
# 5    AK23                                    TriceraTop Spin
# 6    AK85                                Na'vi River Journey
# 7    AK86                           Avatar Flight of Passage
# 8    CA03        Monsters, Inc. Mike & Sulley to the Rescue!
# 9    CA06                  The Twilight Zone Tower of Terror
# 10   CA09                           Soarin' Around the World
# 11  CA109                            Radiator Springs Racers
# 12  CA110                          Mater's Junkyard Jamboree
# 13   CA12                                  Grizzly River Run
# ...

# %%
#converting the open_on column to date data type
df['opened_on'] = pd.to_datetime(df['opened_on'])
df
# Out:
#     code                                               name  \
# 0   AK01                            It's Tough to Be a Bug!
# 1   AK07                                Kilimanjaro Safaris
# 2   AK11  Expedition Everest - Legend of the Forbidden M...
# 3   AK14                                  Kali River Rapids
# 4   AK18                                           DINOSAUR
# ..   ...                                                ...
# 90  MK39                                      Astro Orbiter
# 91  MK40                         Monsters, Inc. Laugh Floor
# 92  MK43                              Tomorrowland Speedway
# 93  MK44         Tomorrowland Transit Authority PeopleMover
# 94  MK96                  See Mickey at Town Square Theater
#
#                 short_name                 land  opened_on  duration  \
# 0   It's Tough to Be a Bug     Discovery Island 1998-04-22      8.00
# 1      Kilimanjaro Safaris               Africa 1998-04-22     20.00
# ...

# %%
#oh oh the dataset is missing rides/attractions opened since 2021. 
df.sort_values(by='opened_on', ascending=False)
# Out:
#      code                                name           short_name  \
# 56  EP186        Remy’s Ratatouille Adventure     Remy's Adventure
# 61  HS111   Mickey & Minnie's Runaway Railway      Runaway Railway
# 63  HS113   Star Wars: Rise of the Resistance   Rise of Resistance
# 62  HS112    Millennium Falcon: Smugglers Run    Millennium Falcon
# 64  HS116  Lightning McQueen's Racing Academy       Racing Academy
# ..    ...                                 ...                  ...
# 29   DL16           Dumbo the Flying Elephant                Dumbo
# 40   DL38                  Peter Pan's Flight   Peter Pan's Flight
# 39   DL37                Mr. Toad's Wild Ride  Mr Toad's Wild Ride
# 35   DL28                       Jungle Cruise        Jungle Cruise
# 24   DL03                             Autopia              Autopia
#
#                         land  opened_on  duration  average_wait_per_hundred
# 56            World Showcase 2021-10-01      5.00                       NaN
# ...

# %%
#converting all the code content to a string
df['code'].str

# %%
#separating 
df['code'].str[:2]
# Out:
# 0     AK
# 1     AK
# 2     AK
# 3     AK
# 4     AK
#       ..
# 90    MK
# 91    MK
# 92    MK
# 93    MK
# 94    MK
# Name: code, Length: 95, dtype: object

# %%
#Creating a new column called park_code
df['park_code'] = df['code'].str[:2]
df
# Out:
#     code                                               name  \
# 0   AK01                            It's Tough to Be a Bug!
# 1   AK07                                Kilimanjaro Safaris
# 2   AK11  Expedition Everest - Legend of the Forbidden M...
# 3   AK14                                  Kali River Rapids
# 4   AK18                                           DINOSAUR
# ..   ...                                                ...
# 90  MK39                                      Astro Orbiter
# 91  MK40                         Monsters, Inc. Laugh Floor
# 92  MK43                              Tomorrowland Speedway
# 93  MK44         Tomorrowland Transit Authority PeopleMover
# 94  MK96                  See Mickey at Town Square Theater
#
#                 short_name                 land  opened_on  duration  \
# 0   It's Tough to Be a Bug     Discovery Island 1998-04-22      8.00
# 1      Kilimanjaro Safaris               Africa 1998-04-22     20.00
# ...

# %%
df.sort_values(by='park_code')
# Out:
#      code                                               name  \
# 0    AK01                            It's Tough to Be a Bug!
# 1    AK07                                Kilimanjaro Safaris
# 2    AK11  Expedition Everest - Legend of the Forbidden M...
# 3    AK14                                  Kali River Rapids
# 4    AK18                                           DINOSAUR
# ..    ...                                                ...
# 71   MK02                 Buzz Lightyear's Space Ranger Spin
# 70   MK01                                     Space Mountain
# 93   MK44         Tomorrowland Transit Authority PeopleMover
# 81  MK177  See Cinderella and a Visiting Princess at Prin...
# 94   MK96                  See Mickey at Town Square Theater
#
#                    short_name                 land  opened_on  duration  \
# 0      It's Tough to Be a Bug     Discovery Island 1998-04-22       8.0
# 1         Kilimanjaro Safaris               Africa 1998-04-22      20.0
# ...

# %%
df_mk = df[df.park_code == 'MK']
df_mk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 70 to 94
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      25 non-null     object
#  1   name                      25 non-null     object
#  2   short_name                25 non-null     object
#  3   land                      25 non-null     object
#  4   opened_on                 25 non-null     datetime64[ns]
#  5   duration                  25 non-null     float64
#  6   average_wait_per_hundred  20 non-null     float64
#  7   park_code                 25 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 1.8+ KB

# %%
#Since I only want the rides/atractions in MK 
df_mk.sort_values(by='opened_on')
# Out:
#      code                                               name  \
# 87   MK29                                      Mad Tea Party
# 74   MK05                                 Peter Pan's Flight
# 86   MK28                               "it's a small world"
# 76   MK13                                      Jungle Cruise
# 92   MK43                              Tomorrowland Speedway
# 85   MK27                          Dumbo the Flying Elephant
# 84   MK26                    Prince Charming Regal Carrousel
# 83   MK23                                The Haunted Mansion
# 80   MK16                           Pirates of the Caribbean
# 70   MK01                                     Space Mountain
# 93   MK44         Tomorrowland Transit Authority PeopleMover
# 72   MK03                      Big Thunder Mountain Railroad
# 73   MK04                                    Splash Mountain
# 90   MK39                                      Astro Orbiter
# ...

# %%
df.park_code.value_counts()
# Out:
# park_code
# DL    25
# MK    25
# CA    14
# HS    12
# EP    11
# AK     8
# Name: count, dtype: int64

# %%
df_mk.sort_values(by='land')
# Out:
#      code                                               name  \
# 80   MK16                           Pirates of the Caribbean
# 76   MK13                                      Jungle Cruise
# 79   MK15                       The Magic Carpets of Aladdin
# 82  MK178  See Princess Tiana and a Visiting Princess at ...
# 85   MK27                          Dumbo the Flying Elephant
# 84   MK26                    Prince Charming Regal Carrousel
# 88   MK30                              Mickey's PhilharMagic
# 81  MK177  See Cinderella and a Visiting Princess at Prin...
# 78  MK142      Under the Sea ~ Journey of the Little Mermaid
# 77  MK141                            Seven Dwarfs Mine Train
# 75   MK06             The Many Adventures of Winnie the Pooh
# 74   MK05                                 Peter Pan's Flight
# 89   MK34                                    The Barnstormer
# 86   MK28                               "it's a small world"
# ...

# %%
df_mk.sort_values(by='code')
# Out:
#      code                                               name  \
# 70   MK01                                     Space Mountain
# 71   MK02                 Buzz Lightyear's Space Ranger Spin
# 72   MK03                      Big Thunder Mountain Railroad
# 73   MK04                                    Splash Mountain
# 74   MK05                                 Peter Pan's Flight
# 75   MK06             The Many Adventures of Winnie the Pooh
# 76   MK13                                      Jungle Cruise
# 77  MK141                            Seven Dwarfs Mine Train
# 78  MK142      Under the Sea ~ Journey of the Little Mermaid
# 79   MK15                       The Magic Carpets of Aladdin
# 80   MK16                           Pirates of the Caribbean
# 81  MK177  See Cinderella and a Visiting Princess at Prin...
# 82  MK178  See Princess Tiana and a Visiting Princess at ...
# 83   MK23                                The Haunted Mansion
# ...

# %%
df_mk.land.value_counts()
# Out:
# land
# Fantasyland            12
# Tomorrowland            6
# Adventureland           3
# Frontierland            2
# Liberty Square          1
# Main Street, U.S.A.     1
# Name: count, dtype: int64

# %%
#I want to add this dataset with the attractions that are missing from the original df.
#mk_missing_attractions was created manually in Google Sheets and dowloaded as a csv.
mk_missing = pd.read_csv("mk_missing_attractions - Sheet1.csv")

# %%
mk_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      14 non-null     object
#  1   name                      14 non-null     object
#  2   short_name                14 non-null     object
#  3   land                      14 non-null     object
#  4   opened_on                 14 non-null     object
#  5   duration                  14 non-null     float64
#  6   average_wait_per_hundred  3 non-null      float64
#  7   park_code                 14 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 1.0+ KB

# %%
mk_missing.head()
# Out:
#     code                               name                    short_name  \
# 0  MK143  Walt Disney's Enchanted Tiki Room          ¡Enchanted Tiki Room
# 1  MK144             Swiss Family Treehouse        Swiss Family Treehouse
# 2  MK145         Walt Disney World Railroad    Walt Disney World Railroad
# 3  MK146              Country Bear Jamboree         Country Bear Jamboree
# 4  MK147       Frontierland Shootin' Arcade  Frontierland Shootin' Arcade
#
#                   land   opened_on  duration  average_wait_per_hundred  \
# 0        Adventureland  1971-10-01      15.5                       NaN
# 1        Adventureland  1971-10-01      13.0                       7.0
# 2  Main Street, U.S.A.  1971-10-01      20.0                       8.0
# 3         Frontierland  1971-10-01      10.0                       NaN
# 4         Frontierland  1971-10-01       3.0                       NaN
#
#   park_code
# 0        MK
# 1        MK
# 2        MK
# 3        MK
# 4        MK

# %%
mk_missing['opened_on'] = pd.to_datetime(mk_missing['opened_on'])
mk_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      14 non-null     object
#  1   name                      14 non-null     object
#  2   short_name                14 non-null     object
#  3   land                      14 non-null     object
#  4   opened_on                 14 non-null     datetime64[ns]
#  5   duration                  14 non-null     float64
#  6   average_wait_per_hundred  3 non-null      float64
#  7   park_code                 14 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 1.0+ KB

# %%
mk_missing.shape
# Out:
# (14, 8)

# %%
df_mk.shape
# Out:
# (25, 8)

# %%
#Adding the dataset I created with the missing attractions to df_mk.
df_mk_all = pd.concat([df_mk, mk_missing])
df_mk_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 70 to 13
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      39 non-null     object
#  1   name                      39 non-null     object
#  2   short_name                39 non-null     object
#  3   land                      39 non-null     object
#  4   opened_on                 39 non-null     datetime64[ns]
#  5   duration                  39 non-null     float64
#  6   average_wait_per_hundred  23 non-null     float64
#  7   park_code                 39 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 2.7+ KB

# %%
#Dropping Splash Mountain because it was closed in 2023 but was included in the original df.
df_mk_all.drop(df_mk_all[(df_mk_all['name'] == 'Splash Mountain')].index, inplace=True)

# %%
df_mk_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 70 to 13
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      38 non-null     object
#  1   name                      38 non-null     object
#  2   short_name                38 non-null     object
#  3   land                      38 non-null     object
#  4   opened_on                 38 non-null     datetime64[ns]
#  5   duration                  38 non-null     float64
#  6   average_wait_per_hundred  22 non-null     float64
#  7   park_code                 38 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 2.7+ KB

# %%
#It would be easier if I have a column with just the year.
df_mk_all['year']= df_mk_all['opened_on'].dt.year
df_mk_all.head()
# Out:
#     code                                    name          short_name  \
# 70  MK01                          Space Mountain      Space Mountain
# 71  MK02      Buzz Lightyear's Space Ranger Spin      Buzz Lightyear
# 72  MK03           Big Thunder Mountain Railroad     Big Thunder Mtn
# 74  MK05                      Peter Pan's Flight  Peter Pan's Flight
# 75  MK06  The Many Adventures of Winnie the Pooh     Winnie the Pooh
#
#             land  opened_on  duration  average_wait_per_hundred park_code  \
# 70  Tomorrowland 1975-01-15      10.0                       3.0        MK
# 71  Tomorrowland 1998-10-07       4.5                       3.0        MK
# 72  Frontierland 1980-09-23       7.0                       2.5        MK
# 74   Fantasyland 1971-10-01       3.0                       5.5        MK
# 75   Fantasyland 1999-06-05       4.0                       4.0        MK
#
#     year
# 70  1975
# 71  1998
# 72  1980
# 74  1971
# 75  1999

# %%
df_mk_all.sort_values('year')
# Out:
#      code                                               name  \
# 3   MK146                              Country Bear Jamboree
# 0   MK143                  Walt Disney's Enchanted Tiki Room
# 1   MK144                             Swiss Family Treehouse
# 87   MK29                                      Mad Tea Party
# 86   MK28                               "it's a small world"
# 85   MK27                          Dumbo the Flying Elephant
# 84   MK26                    Prince Charming Regal Carrousel
# 83   MK23                                The Haunted Mansion
# 2   MK145                         Walt Disney World Railroad
# 92   MK43                              Tomorrowland Speedway
# 4   MK147                       Frontierland Shootin' Arcade
# 6   MK149                             The Hall of Presidents
# 76   MK13                                      Jungle Cruise
# 74   MK05                                 Peter Pan's Flight
# ...

# %%
#I want to know how many attractions opened before and after 1993, when I first visited with my family.
df_mk_all[df_mk_all.year < 1993].value_counts('year')
# Out:
# year
# 1971    14
# 1973     3
# 1975     3
# 1980     1
# Name: count, dtype: int64

# %%
#I want to know how many attractions opened before and after 1993, when I first visited with my family.
df_mk_all[df_mk_all.year > 1993].value_counts('year')
# Out:
# year
# 2012    5
# 2016    2
# 1995    1
# 1996    1
# 1998    1
# 1999    1
# 2001    1
# 2003    1
# 2007    1
# 2011    1
# 2014    1
# 2023    1
# Name: count, dtype: int64

# %%
#Total number of facilities per land
df_mk_all.land.value_counts()
# Out:
# land
# Fantasyland            16
# Tomorrowland            8
# Adventureland           5
# Frontierland            4
# Liberty Square          3
# Main Street, U.S.A.     2
# Name: count, dtype: int64

# %%
#Convert the column year to datetime type
df_mk_all['year'] = pd.to_datetime(df_mk_all['year'])
df_mk_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 70 to 13
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      38 non-null     object
#  1   name                      38 non-null     object
#  2   short_name                38 non-null     object
#  3   land                      38 non-null     object
#  4   opened_on                 38 non-null     datetime64[ns]
#  5   duration                  38 non-null     float64
#  6   average_wait_per_hundred  22 non-null     float64
#  7   park_code                 38 non-null     object
#  8   year                      38 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 3.0+ KB

# %%
#distribution of attractions' opennings 
df_mk_all.hist()
# Out:
# array([[<Axes: title={'center': 'opened_on'}>,
#         <Axes: title={'center': 'duration'}>],
#        [<Axes: title={'center': 'average_wait_per_hundred'}>,
#         <Axes: title={'center': 'year'}>]], dtype=object)

# %%
#How old are facilities in each land?df.groupby(by='continent').life_expectancy.median()
# df['gdp_per_capita'] = df.gdp / df.population
today = pd.to_datetime('today')
df_mk_all['age'] = today.year - df_mk_all['opened_on'].dt.year
df_mk_all.head()
df_mk_all.sort_values(by='age').head(10)
# Out:
#      code                                               name  \
# 8   MK151                              TRON Lightcycle / Run
# 81  MK177  See Cinderella and a Visiting Princess at Prin...
# 82  MK178  See Princess Tiana and a Visiting Princess at ...
# 77  MK141                            Seven Dwarfs Mine Train
# 13  MK156                    Meet Merida at Fairytale Garden
# 11  MK154                         Enchanted Tales with Belle
# 10  MK153                           Meet Ariel in Her Grotto
# 78  MK142      Under the Sea ~ Journey of the Little Mermaid
# 12  MK155                             Pete's Silly Side Show
# 94   MK96                  See Mickey at Town Square Theater
#
#                     short_name                 land  opened_on  duration  \
# 8        TRON Lightcycle / Run         Tomorrowland 2023-04-04       1.0
# 81   Princess Hall: Cinderella          Fantasyland 2016-11-24      10.0
# ...

# %%
df_mk_all.hist('age')
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
#What's the median age of the attractions?
#This means half of the attractions are at least 48 years old! 
df_mk_all.age.median()
# Out:
# 48.0

# %%
#What's the mean of the attractions?
df_mk_all.age.mean().astype(int)
# Out:
# 34

# %%
#Lands with the oldest attractions
df_mk_all.groupby(by='land').age.median().astype(int).sort_values()
#print("Fantasyland is the youngest land")
# Out:
# land
# Fantasyland            15
# Main Street, U.S.A.    32
# Tomorrowland           38
# Frontierland           51
# Adventureland          52
# Liberty Square         52
# Name: age, dtype: int64

# %%
df_mk_all.groupby(by='land').age.mean().astype(int).sort_values()
# Out:
# land
# Fantasyland            25
# Main Street, U.S.A.    32
# Tomorrowland           33
# Adventureland          45
# Frontierland           49
# Liberty Square         51
# Name: age, dtype: int64

# %%
#Ho many attractions --that are still open-- were operational in 1993? 21
(df_mk_all[df_mk_all.year <= pd.to_datetime(1993)])
# Out:
#      code                                        name  \
# 70   MK01                              Space Mountain
# 72   MK03               Big Thunder Mountain Railroad
# 74   MK05                          Peter Pan's Flight
# 76   MK13                               Jungle Cruise
# 80   MK16                    Pirates of the Caribbean
# 83   MK23                         The Haunted Mansion
# 84   MK26             Prince Charming Regal Carrousel
# 85   MK27                   Dumbo the Flying Elephant
# 86   MK28                        "it's a small world"
# 87   MK29                               Mad Tea Party
# 92   MK43                       Tomorrowland Speedway
# 93   MK44  Tomorrowland Transit Authority PeopleMover
# 0   MK143           Walt Disney's Enchanted Tiki Room
# 1   MK144                      Swiss Family Treehouse
# 2   MK145                  Walt Disney World Railroad
# 3   MK146                       Country Bear Jamboree
# ...

# %%
#percentage of attractions that existed in 1993
int(21*100/38)
# Out:
# 55

# %%
#How many attractions opened (and are still open) after I visited in 1993? 17
(df_mk_all[df_mk_all.year > pd.to_datetime(1993)])
# Out:
#      code                                               name  \
# 71   MK02                 Buzz Lightyear's Space Ranger Spin
# 75   MK06             The Many Adventures of Winnie the Pooh
# 77  MK141                            Seven Dwarfs Mine Train
# 78  MK142      Under the Sea ~ Journey of the Little Mermaid
# 79   MK15                       The Magic Carpets of Aladdin
# 81  MK177  See Cinderella and a Visiting Princess at Prin...
# 82  MK178  See Princess Tiana and a Visiting Princess at ...
# 88   MK30                              Mickey's PhilharMagic
# 89   MK34                                    The Barnstormer
# 90   MK39                                      Astro Orbiter
# 91   MK40                         Monsters, Inc. Laugh Floor
# 94   MK96                  See Mickey at Town Square Theater
# 8   MK151                              TRON Lightcycle / Run
# 10  MK153                           Meet Ariel in Her Grotto
# ...

# %%
#How many attractions were opened (and are still open) since my parents first visit in 1975? 20
(df_mk_all[df_mk_all.year <= pd.to_datetime(1975)])
# Out:
#      code                                        name  \
# 70   MK01                              Space Mountain
# 74   MK05                          Peter Pan's Flight
# 76   MK13                               Jungle Cruise
# 80   MK16                    Pirates of the Caribbean
# 83   MK23                         The Haunted Mansion
# 84   MK26             Prince Charming Regal Carrousel
# 85   MK27                   Dumbo the Flying Elephant
# 86   MK28                        "it's a small world"
# 87   MK29                               Mad Tea Party
# 92   MK43                       Tomorrowland Speedway
# 93   MK44  Tomorrowland Transit Authority PeopleMover
# 0   MK143           Walt Disney's Enchanted Tiki Room
# 1   MK144                      Swiss Family Treehouse
# 2   MK145                  Walt Disney World Railroad
# 3   MK146                       Country Bear Jamboree
# 4   MK147                Frontierland Shootin' Arcade
# ...

# %%
df_mk_all.to_csv('df_mk_all.csv')

# %%
#I want to find the common facilities opened between certain years
